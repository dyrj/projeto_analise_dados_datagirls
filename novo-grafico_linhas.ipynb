# %% [markdown]
# <a href="https://colab.research.google.com/github/dyrj/projeto_analise_dados_datagirls/blob/main/novo-grafico_linhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print ("Hello Data Girls")
# Out:
# Hello Data Girls

# %%
# importacao de bibliotecas
import random
import matplotlib.pyplot as plt

# Gerar uma lista com 10 números aleatórios entre 1 e 100
dados = [random.randint(1, 100) for _ in range(10)]

# Exibir a lista gerada
print("Lista de dados:", dados)

# Plotar os dados
plt.plot(dados, marker='o') # marcador em cada ponto para melhor visualização
plt.title("Gráfico de Números Aleatórios")
plt.xlabel("Índice")
plt.ylabel("Valor")
plt.grid(True)
plt.show()
# Out:
# Lista de dados: [81, 53, 72, 92, 39, 3, 24, 54, 13, 83]
